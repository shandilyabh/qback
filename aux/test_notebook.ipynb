# %%
import pandas as pd
df = pd.read_csv('NIFTY-Options-Weekly.csv')
print(df.columns)
# Out:
# Index(['timestamp', 'expiry', 'strike', 'option_type', 'open', 'high', 'low',
#        'close', 'volume', 'oi'],
#       dtype='object')

# %%
from tqdm import tqdm

for i in tqdm(range(len(df))):
    df.iloc[i].get("close")
# Out:
# 100%|██████████| 135360/135360 [00:02<00:00, 52292.13it/s]

# %%
df.head()
# Out:
#              timestamp               expiry  strike option_type    open  \
# 0  2024-01-01 09:15:00  2024-01-04 00:00:00   19600          CE  212.40
# 1  2024-01-01 09:15:00  2024-01-04 00:00:00   19600          PE   25.39
# 2  2024-01-01 09:15:00  2024-01-04 00:00:00   19650          CE  186.11
# 3  2024-01-01 09:15:00  2024-01-04 00:00:00   19650          PE   52.01
# 4  2024-01-01 09:15:00  2024-01-04 00:00:00   19700          CE  158.67
#
#      high     low   close  volume    oi
# 0  215.92  210.48  213.24     307  1771
# 1   25.72   24.68   24.95     323  2078
# 2  194.97  184.98  194.60     306  1848
# 3   53.15   51.84   53.02     318  1859
# 4  159.54  158.05  158.61     289  2004

# %% [markdown]
# since both the csvs are synthetically generated, they are assumed to have no irregular or missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135360 entries, 0 to 135359
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   timestamp    135360 non-null  object
#  1   expiry       135360 non-null  object
#  2   strike       135360 non-null  int64
#  3   option_type  135360 non-null  object
#  4   open         135360 non-null  float64
#  5   high         135360 non-null  float64
#  6   low          135360 non-null  float64
#  7   close        135360 non-null  float64
#  8   volume       135360 non-null  int64
#  9   oi           135360 non-null  int64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 10.3+ MB

# %%
type(df.iloc[1]["expiry"])
# Out:
# str

# %%
df.sample(20)
# Out:
#                   timestamp               expiry  strike option_type    open  \
# 111987  2024-01-23 12:40:00  2024-01-25 00:00:00   19700          PE  131.36
# 40089   2024-01-08 15:02:00  2024-01-11 00:00:00   19650          PE   56.14
# 4882    2024-01-01 13:46:00  2024-01-04 00:00:00   19650          CE  155.58
# 89187   2024-01-18 10:21:00  2024-01-18 00:00:00   19900          PE  188.70
# 95919   2024-01-19 10:19:00  2024-01-25 00:00:00   20050          PE  198.03
# 127783  2024-01-25 14:46:00  2024-01-25 00:00:00   19300          PE   24.81
# 100119  2024-01-19 14:13:00  2024-01-25 00:00:00   19700          PE   43.16
# 108227  2024-01-22 15:27:00  2024-01-25 00:00:00   19750          PE  131.59
# 105035  2024-01-22 12:30:00  2024-01-25 00:00:00   19650          PE   76.28
# 98346   2024-01-19 12:34:00  2024-01-25 00:00:00   19950          CE   81.39
# 60282   2024-01-11 14:56:00  2024-01-11 00:00:00   19600          CE  214.35
# ...

# %%
option_price_dict = {}
for row in df.itertuples(index=False):
    key = (row.timestamp, row.expiry, row.strike, row.option_type)
    option_price_dict[key] = row.close

# %%
option_price_dict
# Out:
# {('2024-01-01 09:15:00', '2024-01-04 00:00:00', 19600, 'CE'): 213.24,
#  ('2024-01-01 09:15:00', '2024-01-04 00:00:00', 19600, 'PE'): 24.95,
#  ('2024-01-01 09:15:00', '2024-01-04 00:00:00', 19650, 'CE'): 194.6,
#  ('2024-01-01 09:15:00', '2024-01-04 00:00:00', 19650, 'PE'): 53.02,
#  ('2024-01-01 09:15:00', '2024-01-04 00:00:00', 19700, 'CE'): 158.61,
#  ('2024-01-01 09:15:00', '2024-01-04 00:00:00', 19700, 'PE'): 80.27,
#  ('2024-01-01 09:15:00', '2024-01-04 00:00:00', 19750, 'CE'): 134.89,
#  ('2024-01-01 09:15:00', '2024-01-04 00:00:00', 19750, 'PE'): 97.81,
#  ('2024-01-01 09:15:00', '2024-01-04 00:00:00', 19800, 'CE'): 118.41,
#  ('2024-01-01 09:15:00', '2024-01-04 00:00:00', 19800, 'PE'): 126.36,
#  ('2024-01-01 09:15:00', '2024-01-04 00:00:00', 19850, 'CE'): 89.41,
#  ('2024-01-01 09:15:00', '2024-01-04 00:00:00', 19850, 'PE'): 148.02,
#  ('2024-01-01 09:15:00', '2024-01-04 00:00:00', 19900, 'CE'): 61.91,
#  ('2024-01-01 09:15:00', '2024-01-04 00:00:00', 19900, 'PE'): 178.6,
# ...

# %%
index_data = pd.read_csv('NIFTY-Index-Monthly-Data.csv')

# %%
index_data.head()
# Out:
#              timestamp  index_close
# 0  2024-01-01 09:15:00     19787.72
# 1  2024-01-01 09:16:00     19791.97
# 2  2024-01-01 09:17:00     19795.22
# 3  2024-01-01 09:18:00     19790.73
# 4  2024-01-01 09:19:00     19788.37

# %%
index_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7520 entries, 0 to 7519
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    7520 non-null   object
#  1   index_close  7520 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 117.6+ KB
